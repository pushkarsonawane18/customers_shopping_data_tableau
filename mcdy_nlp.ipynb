# %% [markdown]
# <a href="https://colab.research.google.com/github/pushkarsonawane18/customers_shopping_data_tableau/blob/main/mcdy_nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import kagglehub
path = kagglehub.dataset_download("nelgiriyewithana/mcdonalds-store-reviews")
# Out:
# Using Colab cache for faster access to the 'mcdonalds-store-reviews' dataset.

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os
import re
import matplotlib.pyplot as plt

# %%
# listing directory path file name
os.listdir(path)
# Out:
# ['McDonald_s_Reviews.csv']

# %%
file_path = os.path.join(path,'McDonald_s_Reviews.csv')

# %%
print(file_path)
# Out:
# /kaggle/input/mcdonalds-store-reviews/McDonald_s_Reviews.csv

# %%
# loading dataset

df = pd.read_csv(file_path, encoding='latin-1')

# %%
# shape
df.shape
# Out:
# (33396, 10)

# %%
df.head()
# Out:
#    reviewer_id  store_name              category  \
# 0            1  McDonald's  Fast food restaurant
# 1            2  McDonald's  Fast food restaurant
# 2            3  McDonald's  Fast food restaurant
# 3            4  McDonald's  Fast food restaurant
# 4            5  McDonald's  Fast food restaurant
#
#                                        store_address  latitude   longitude  \
# 0  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 1  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 2  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 3  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 4  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
#
#   rating_count   review_time  \
# 0        1,240  3 months ago
# 1        1,240    5 days ago
# 2        1,240    5 days ago
# 3        1,240   a month ago
# 4        1,240  2 months ago
#
# ...

# %%
df.dtypes
# Out:
# reviewer_id        int64
# store_name        object
# category          object
# store_address     object
# latitude         float64
# longitude        float64
# rating_count      object
# review_time       object
# review            object
# rating            object
# dtype: object

# %%
df['store_name'].value_counts()
# Out:
# store_name
# McDonald's       33325
# ýýýMcDonald's       71
# Name: count, dtype: int64

# %%
df['category'].value_counts()
# Out:
# category
# Fast food restaurant    33396
# Name: count, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# 5 stars    10274
# 1 star      9431
# 4 stars     5787
# 3 stars     4818
# 2 stars     3086
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# reviewer_id        0
# store_name         0
# category           0
# store_address      0
# latitude         660
# longitude        660
# rating_count       0
# review_time        0
# review             0
# rating             0
# dtype: int64

# %%
# Cleaning rating col

df['rating'] = df['rating'].str.replace(" stars","",regex=False)

# %%
df['rating'].value_counts()
# Out:
# rating
# 5         10274
# 1 star     9431
# 4          5787
# 3          4818
# 2          3086
# Name: count, dtype: int64

# %%
# Cleaning rating col

df['rating'] = df['rating'].str.replace(" star","",regex=False)

# %%
df['rating'].value_counts()
# Out:
# rating
# 5    10274
# 1     9431
# 4     5787
# 3     4818
# 2     3086
# Name: count, dtype: int64

# %%
# Cleaning Store name col

df['store_name'] = df['store_name'].str.replace(r"^[^a-zA-Z]+","",regex=True)

# %%
df['store_name'] = df['store_name'].str.replace("'","")

# %%
df['store_name'].value_counts()
# Out:
# store_name
# McDonalds    33396
# Name: count, dtype: int64

# %%
# clean rating count

df['rating_count'] = df['rating_count'].str.replace(',','')

# %%
df.shape
# Out:
# (33396, 10)

# %%
# Clean review col

df['review'].head(20)
# Out:
# 0     Why does it look like someone spit on my food?...
# 1     It'd McDonalds. It is what it is as far as the...
# 2     Made a mobile order got to the speaker and che...
# 3     My mc. Crispy chicken sandwich was ï¿½ï¿½ï¿½ï¿...
# 4     I repeat my order 3 times in the drive thru, a...
# 5     I work for door dash and they locked us all ou...
# 6     If I  could give this location a zero on custo...
# 7     Came in and ordered a Large coffee w/no ice. T...
# 8     Went thru drive thru. Ordered. Getting home no...
# 9     I'm not really a huge fan of fast food, but I ...
# 10    Worst McDonaldï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿...
# 11    We stopped by for a quick breakfast.  It was n...
# 12    The morning crew seems fast and efficient. Nig...
# 13    Today, i was disappointed in that restaurant #...
# 14    Ordered food burger wrong and left out part of...
# 15    This was a dine in experience. The tables were...
# 16    The line wS extremely big and was moving very ...
# ...

# %%
special_chars = set()

for i in df['review'].dropna():
  found = re.findall(r'[^\x00-\x7f]',i)
  special_chars.update(found)

print(special_chars)
# Out:
# {'ï', '½', 'ý', '¿'}

# %%
df['review'] = df['review'].str.replace(r'[^\x00-\x7f]','',regex=True)

# %%
special_chars = set()

for i in df['review'].dropna():
  found = re.findall(r'[^\x00-\x7f]',i)
  special_chars.update(found)

print(special_chars)
# Out:
# set()

# %%
df.head()
# Out:
#    reviewer_id store_name              category  \
# 0            1  McDonalds  Fast food restaurant
# 1            2  McDonalds  Fast food restaurant
# 2            3  McDonalds  Fast food restaurant
# 3            4  McDonalds  Fast food restaurant
# 4            5  McDonalds  Fast food restaurant
#
#                                        store_address  latitude   longitude  \
# 0  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 1  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 2  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 3  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 4  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
#
#   rating_count   review_time  \
# 0         1240  3 months ago
# 1         1240    5 days ago
# 2         1240    5 days ago
# 3         1240   a month ago
# 4         1240  2 months ago
#
# ...

# %%
df.columns
# Out:
# Index(['reviewer_id', 'store_name', 'category', 'store_address', 'latitude ',
#        'longitude', 'rating_count', 'review_time', 'review', 'rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# reviewer_id        int64
# store_name        object
# category          object
# store_address     object
# latitude         float64
# longitude        float64
# rating_count      object
# review_time       object
# review            object
# rating            object
# dtype: object

# %%
df['rating'] = df['rating'].astype(int)

# %%
def label_sentiment(rating):
  if rating >= 4:
    return 'positive'
  elif rating == 3:
    return 'neutral'
  else:
    return 'negative'

# %%
df['sentiment'] = df['rating'].apply(label_sentiment)

# %%
df.head()
# Out:
#    reviewer_id store_name              category  \
# 0            1  McDonalds  Fast food restaurant
# 1            2  McDonalds  Fast food restaurant
# 2            3  McDonalds  Fast food restaurant
# 3            4  McDonalds  Fast food restaurant
# 4            5  McDonalds  Fast food restaurant
#
#                                        store_address  latitude   longitude  \
# 0  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 1  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 2  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 3  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 4  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
#
#   rating_count   review_time  \
# 0         1240  3 months ago
# 1         1240    5 days ago
# 2         1240    5 days ago
# 3         1240   a month ago
# 4         1240  2 months ago
#
# ...

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    16061
# negative    12517
# neutral      4818
# Name: count, dtype: int64

# %% [markdown]
# # Text Preprocessing

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
stop_words = set(stopwords.words('english'))

# %%
import string

# %%
def text_preprocess(text):
  text = text.lower() # for lowercase
  text = text.translate(str.maketrans('','',string.punctuation)) # for punctuations
  tokens = word_tokenize(text) # for tokenize
  tokens = [t for t in tokens if t not in stop_words]
  return ' '.join(tokens)

# %%
df['cleaned_review'] = df['review'].dropna().apply(text_preprocess)

# %%
df['cleaned_review'].head()
# Out:
# 0    look like someone spit food normal transaction...
# 1    itd mcdonalds far food atmosphere go staff mak...
# 2    made mobile order got speaker checked line mov...
# 3    mc crispy chicken sandwich customer service qu...
# 4    repeat order 3 times drive thru still manage m...
# Name: cleaned_review, dtype: object

# %%
from nltk.stem import PorterStemmer # stemming
from nltk.stem import WordNetLemmatizer # lemmitization

# %%
stemmer = PorterStemmer()

# %%
lemmatizer = WordNetLemmatizer()

# %%
words = ['running','walking','cooking','happily','studying','reading','writing','sleeping','screaming','screening','streaming','dogs','cats']

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
print(lemmatizer.lemmatize('running', pos ='v'))
# Out:
# run

# %%
print("word   stemming    lemmitization")
print("-")
for word in words:
  print(f"{word:<11} {stemmer.stem(word):<11}  {lemmatizer.lemmatize(word)}")
# Out:
# word   stemming    lemmitization
# -
# running     run          running
# walking     walk         walking
# cooking     cook         cooking
# happily     happili      happily
# studying    studi        studying
# reading     read         reading
# writing     write        writing
# sleeping    sleep        sleeping
# screaming   scream       screaming
# screening   screen       screening
# streaming   stream       streaming
# dogs        dog          dog
# cats        cat          cat

# %%
df['store_name'] = df['store_name'].str.lower()

# %%
df.head()
# Out:
#    reviewer_id  store_name              category  \
# 0            1         NaN  Fast food restaurant
# 1            2         NaN  Fast food restaurant
# 2            3         NaN  Fast food restaurant
# 3            4         NaN  Fast food restaurant
# 4            5         NaN  Fast food restaurant
#
#                                        store_address  latitude   longitude  \
# 0  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 1  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 2  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 3  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 4  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
#
#   rating_count   review_time  \
# 0         1240  3 months ago
# 1         1240    5 days ago
# 2         1240    5 days ago
# 3         1240   a month ago
# 4         1240  2 months ago
#
# ...

# %%
df['category'] = df['category'].str.lower()

# %%
df.head()
# Out:
#    reviewer_id  store_name              category  \
# 0            1         NaN  fast food restaurant
# 1            2         NaN  fast food restaurant
# 2            3         NaN  fast food restaurant
# 3            4         NaN  fast food restaurant
# 4            5         NaN  fast food restaurant
#
#                                        store_address  latitude   longitude  \
# 0  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 1  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 2  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 3  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 4  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
#
#   rating_count   review_time  \
# 0         1240  3 months ago
# 1         1240    5 days ago
# 2         1240    5 days ago
# 3         1240   a month ago
# 4         1240  2 months ago
#
# ...

# %%
df.isnull().sum()
# Out:
# reviewer_id           0
# store_name        33396
# category              0
# store_address         0
# latitude            660
# longitude           660
# rating_count          0
# review_time           0
# review                0
# rating                0
# sentiment             0
# cleaned_review        0
# dtype: int64

# %%
df.shape
# Out:
# (33396, 12)
